# %% [markdown]
# # Species Segmentation with Cluster Analysis

# %% [markdown]
# The Iris flower dataset is one of the most popular ones for machine learning. You can read a lot about it online and have probably already heard of it: https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# We didn't want to use it in the lectures, but believe that it would be very interesting for you to try it out (and maybe read about it on your own).
#
# There are 4 features: sepal length, sepal width, petal length, and petal width.
#
# ***
#
# You have already solved the first exercise, so you can start from there (you've done taken advantage of the Elbow Method).
#
# Plot the data with 2, 3 and 5 clusters. What do you think that means?
#
# Finally, import the CSV with the correct answers (iris_with_answers.csv) and check if the clustering worked as expected. Note that this is not how we usually go about clustering problems. If we have the answers prior to that, we would go for classification (e.g. a logistic regression).

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'iris_dataset.csv'</i>.

# %%
# Load the data
data = pd.read_csv('iris-dataset.csv')
# Check the data
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Plot the data

# %% [markdown]
# For this exercise, try to cluster the iris flowers by the shape of their sepal.
#
# <i> Use the 'sepal_length' and 'sepal_width' variables.</i>

# %%
# create a scatter plot based on two corresponding features (sepal_length and sepal_width; OR petal_length and petal_width)
plt.scatter(data['sepal_length'],data['sepal_width'])
# name your axes
plt.xlabel('Lenght of sepal')
plt.ylabel('Width of sepal')
plt.show()

# %% [markdown]
# ## Clustering (unscaled data)

# %%
# create a variable which will contain the data for the clustering
x = data.copy()
# create a k-means object with 2 clusters
kmeans = KMeans(2)
# fit the data
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
# create a copy of data, so we can see the clusters next to the original data
clusters = data.copy()
# predict the cluster for each observation
clusters['cluster_pred']=kmeans.fit_predict(x)

# %%
# create a scatter plot based on two corresponding features (sepal_length and sepal_width; OR petal_length and petal_width)
plt.scatter(clusters['sepal_length'], clusters['sepal_width'], c= clusters ['cluster_pred'], cmap = 'rainbow')

# %% [markdown]
# ## Standardize the variables

# %% [markdown]
# Import and use the <i> scale </i> method from sklearn to standardize the data.

# %%
# import some preprocessing module
from sklearn import preprocessing

# scale the data for better results
x_scaled = preprocessing.scale(data)
x_scaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %% [markdown]
# ## Clustering (scaled data)

# %%
# create a k-means object with 2 clusters
kmeans_scaled = KMeans(2)
# fit the data
kmeans_scaled.fit(x_scaled)
# Out:
# KMeans(n_clusters=2)

# %%
# create a copy of data, so we can see the clusters next to the original data
clusters_scaled = data.copy()
# predict the cluster for each observation
clusters_scaled['cluster_pred']=kmeans_scaled.fit_predict(x_scaled)

# %%
# create a scatter plot based on two corresponding features (sepal_length and sepal_width; OR petal_length and petal_width)
plt.scatter(clusters_scaled['sepal_length'], clusters_scaled['sepal_width'], c= clusters_scaled ['cluster_pred'], cmap = 'rainbow')

# %% [markdown]
# Looks like the two solutions are identical. That is because the original features have very similar scales to start with!

# %% [markdown]
# ## Take Advantage of the Elbow Method

# %% [markdown]
# ### WCSS

# %%
wcss = []
# 'cl_num' is a that keeps track the highest number of clusters we want to use the WCSS method for. 
# We have it set at 10 right now, but it is completely arbitrary.
cl_num = 10
for i in range (1,cl_num):
    kmeans= KMeans(i)
    kmeans.fit(x_scaled)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
wcss
# Out:
# [600.0000000000003,
#  223.73200573676343,
#  140.96581663074699,
#  114.60278879607732,
#  91.07563926881433,
#  81.9139191670733,
#  72.38028327771453,
#  62.90427477285941,
#  55.33816687021365]

# %% [markdown]
# ### The Elbow Method

# %%
number_clusters = range(1,cl_num)
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %% [markdown]
# ## Understanding the Elbow Curve
#
# Construct and compare the scatter plots to determine which number of clusters is appropriate for further use in our analysis. Based on the Elbow Curve, 2, 3 or 5 seem the most likely.

# %% [markdown]
# ## 2 clusters
#
# Start by separating the standardized data into 2 clusters (you've already done that!)

# %%
kmeans_2 = KMeans(2)
kmeans_2.fit(x_scaled)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# Construct a scatter plot of the original data using the standardized clusters

# %%
c_2 = x.copy()
c_2['c_pred'] = kmeans_2.fit_predict(x_scaled)

# %%
plt.scatter(c_2['sepal_length'], c_2['sepal_width'], c=c_2['c_pred'], cmap = 'rainbow')
plt.xlabel('Sepal Length', fontsize = 20)
plt.ylabel('Sepal width', fontsize = 20)
plt.show()

# %% [markdown]
# ## 3 clusters
# Redo the same for 3 and 5 clusters

# %%
kmeans_3 = KMeans(3)
kmeans_3.fit(x_scaled)
# Out:
# KMeans(n_clusters=3)

# %%
c_3 = x.copy()
c_3['c_pred'] = kmeans_3.fit_predict(x_scaled)

# %%
plt.scatter(c_3['sepal_length'], c_3['sepal_width'], c=c_3['c_pred'], cmap = 'rainbow')
plt.xlabel('Sepal Length', fontsize = 20)
plt.ylabel('Sepal width', fontsize = 20)
plt.show()

# %% [markdown]
# ## 5 clusters

# %%
kmeans_5 = KMeans(5)
kmeans_5.fit(x_scaled)
# Out:
# KMeans(n_clusters=5)

# %%
c_5 = x.copy()
c_5['c_pred'] = kmeans_5.fit_predict(x_scaled)

# %%
plt.scatter(c_5['sepal_length'], c_5['sepal_width'], c=c_5['c_pred'], cmap = 'rainbow')
plt.xlabel('Sepal Length', fontsize = 20)
plt.ylabel('Sepal width', fontsize = 20)
plt.show()

# %% [markdown]
# ## Compare your solutions to the original iris dataset
#
# The original (full) iris data is located in <i>iris_with_answers.csv</i>. Load the csv, plot the data and compare it with your solution.
#
# Obviously there are only 3 types, because that's the original (truthful) iris dataset.
#
# The 2-cluster solution seemed good, but in real life the iris dataset has 3 SPECIES (a 3-cluster solution). Therefore, clustering cannot be trusted at all times. Sometimes it seems like x clusters are a good solution, but in real life, there are more (or less).

# %%
answers = pd.read_csv('iris-with-answers.csv')
answers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
answers['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
answers['species'] = answers['species'].map({'setosa':0, 'versicolor':1, 'virginica':2})
answers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
plt.scatter(answers['sepal_length'], answers['sepal_width'], c = answers['species'], cmap = 'rainbow')
plt.xlabel('Sepal Length', fontsize = 20)
plt.ylabel('Sepal width', fontsize = 20)
plt.show()

# %%
plt.scatter(answers['petal_length'], answers['petal_width'], c=answers['species'], cmap='rainbow')
plt.xlabel('Petal Length', fontsize = 20)
plt.ylabel('Petal width', fontsize = 20)
plt.show()

# %%
plt.scatter(c_3['sepal_length'], c_3['sepal_width'], c=c_3['c_pred'], cmap = 'rainbow')
plt.xlabel('Sepal Length', fontsize = 20)
plt.ylabel('Sepal width', fontsize = 20)
plt.show()

# %%
plt.scatter(c_3['petal_length'], c_3['petal_width'], c=c_3['c_pred'], cmap = 'rainbow')
plt.xlabel('Petal Length', fontsize = 20)
plt.ylabel('Petal width', fontsize = 20)
plt.show()

# %% [markdown]
# ## Interpretation
# The clusters are more defined in the petal scatter plot for both datasets, indicating that what actually makes the species different are petals and not the sepals.
